# %% [markdown]
# # 04.09.23

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## Data visualization is a concept of graphical representation of data or info using visual elements like graphs, charts, and maps.
# ## This reprsentation helps us in understanding the patterns, trends, and outliers in the data and it makes data easily understandable and explainable.
#
# ## By making use of DV, a huge chunk of complex data can be displayed in a way that is easy to understand and is also appealing to the eyes.
#
# ## In DV, plot is a basic structure for the graphical representation of data.

# %% [markdown]
# # PLOTS

# %% [markdown]
# ## A plot is the basic visualization element that helps to visualize the data. To visualize(plot) the data, required is figure and axes objects.
#
#
# *   Figure: It's the top-level container that acts as the window or page on which everything is drawn. It can contain multiple independent subplots, multiple Axes, a title, a legend, etc.
#
# *   Axes: They're the area on which data is plotted. It can have labels or ticks associated with it. There can be multiple Axes in a figure. But a given Axes object can only be in one figure.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ANATOMY OF A PLOT

# %% [markdown]
# ## A plot comprises several elements such as title, label, axes, legned, etc, that adds more mreaning to the visualization.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Components of a plot:
#
#
#
# *   Title: Name of the plot.
# *   Axis: Consists of the X and Y asix which provide the horizonatl and vertical coordinates of the data points.
#
# *   Labels: Used to name the X and Y axis.
# *   Legend: Set of key-value pairs that contains the list of plots and their respective labels.
