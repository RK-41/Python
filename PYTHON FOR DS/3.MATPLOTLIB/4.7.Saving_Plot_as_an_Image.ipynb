# %% [markdown]
# # 09.09.23

# %% [markdown]
# ## Figure can be saved as an image in the local system using Matplotlib.
# ## This will help document the plots easily.
# ## The 'fig.savefig()' function is used for this funcitonality.

# %% [markdown]
# ### Creating a DataFrame for the data set of cars:

# %%
import pandas as pd

# creating a dataframe of data of cars
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON FOR DS/0.FILES TO BE USED/auto_mpg.csv')

# %% [markdown]
# ### Creating a DataFrame containing the mean values of mileage, horsepower and the weight of the cars based on the model year:

# %%
line_df = df.groupby(by = ['model_year'])

# creating a sub-dataframe for the line graph
line_df = line_df.mean()
# Out:
# <ipython-input-4-a00cd7a8eaab>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   line_df = line_df.mean()

# %% [markdown]
# ### Plotting a Line Chart to visualize relationship b/w mileage, horsepower and weight of cars in different years:

# %%
import matplotlib.pyplot as plt

# creating an empty canvas/fig
fig = plt.figure(figsize=[8,4])

# setting axes as [left, bottom, width, height]
ax = fig.add_axes([0,0,1,1])

# plotting the lines
ax.plot(line_df['mpg']/10, label='Mileage', linestyle='-.', linewidth=2)
ax.plot(line_df['horsepower']/100, label='Horsepower', linestyle=':', linewidth=3)
ax.plot(line_df['weight']/1000, label='Weight', linestyle='--', linewidth=2)

# setting title, xlabel and ylabel
ax.set_title('Mileage vs Horsepower vs Weight', fontsize=15)
ax.set_xlabel('Model Year', fontsize=12)
ax.set_ylabel('Values', fontsize=12)

ax.legend()

fig.show()

# %% [markdown]
# ### Saving the figure:

# %%
fig.savefig("Mileage-Horsepower-Weight-LineChart.jpg", dpi=200)

# %% [markdown]
# ### The image is as "Mileage-Horsepower-Weight-LineChart.jpg".
# ### 'dpi' - Dots Per Inch, indicates the resolution of the image, higher the no., more will be the resolution.

# %% [markdown]
# ## While using 'plt.plot()' to create a plot, 'plt.savefig()' can be used to save the figure as an image.
#
# ## Syntax:
# > plt.savefig("filename.jpg", dpi = 200)
