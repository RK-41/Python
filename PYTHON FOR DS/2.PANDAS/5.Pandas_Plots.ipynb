# %% [markdown]
# # PANDAS PLOTS

# %% [markdown]
# ## Pandas provides options to visualize the data.
# ## Syntax:
#
#
# > df.plot(x, y, marker, kind)
#
# *   x: value on x-axis.
#
# *   y: value on y-axis.
#
# *   marker: shape in case of specific plots like a scatter plot.
#
# *   kind: type of plot.

# %% [markdown]
# ## Creating DataFrame of Car Details:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON FOR DS/0.FILES TO BE USED/auto_mpg.csv')
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %% [markdown]
# ## A scatter plot to visualize the trend of acceleration in different years:

# %%
df.plot(x='model_year', y='acceleration', marker='o', kind='scatter')
# Out:
# <Axes: xlabel='model_year', ylabel='acceleration'>

# %% [markdown]
# ## A bar plot to visualize mean acceleration in different years:

# %%
df.groupby('model_year').mean()[['acceleration']].plot(kind='bar')
# Out:
# <ipython-input-8-89038350e452>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('model_year').mean()[['acceleration']].plot(kind='bar')
# <Axes: xlabel='model_year'>

# %% [markdown]
# ## A histogram to visualize the frequency distribution of cylinders:

# %%
df['cylinders'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## A scatter plot to visualize the relaitonship between weight and mpg:

# %%
df.plot(x='weight', y='mpg', kind='scatter')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# ## A bar plot to visualize the sorted mean values of acceleration with respect to no. of cylinders:

# %%
df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind='bar')
# Out:
# <ipython-input-11-b84d46444db7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind='bar')
# <Axes: xlabel='cylinders'>
